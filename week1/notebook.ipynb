# %%
from scipy import misc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im_arr = misc.imread('./test.png')
plt.imshow(im_arr)

# %%
import task5

# %%
gray = task5.make_gray(im_arr)
plt.imshow(gray, cmap='gray')

# %%
gray_np = task5.make_gray_np(im_arr)
plt.imshow(gray_np, cmap='gray')
